# %%
from google.colab import drive
drive.mount('/content/gdrive')
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
pd.__version__
# Out:
# Mounted at /content/gdrive
# '1.3.5'

# %%
file_path = '/content/gdrive/MyDrive/Capstone Project/Data/tweets_sentiment_btc_final_10p.csv'
btc_df = pd.read_csv(file_path)
btc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1810 entries, 0 to 1809
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1810 non-null   object
#  1   Date             1810 non-null   object
#  2   Open             1810 non-null   float64
#  3   High             1810 non-null   float64
#  4   Low              1810 non-null   float64
#  5   Close            1810 non-null   float64
#  6   Adj Close        1810 non-null   float64
#  7   Volume           1810 non-null   int64
#  8   num_tweets       1810 non-null   int64
#  9   tb_subjectivity  1810 non-null   float64
#  10  tb_polarity      1810 non-null   float64
#  11  hf_sentiment     1810 non-null   float64
#  12  fl_sentiment     1810 non-null   float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 184.0+ KB

# %%
dr = btc_df[['Open', 'num_tweets']]
dr.plot()
plt.title('BTC values');

# %%
dr = btc_df[['tb_polarity']]
dr.plot()
plt.title('Sentiment');

# %%
dr = btc_df[['hf_sentiment']]
dr.plot()
plt.title('Sentiment');

# %%
dr = btc_df[['fl_sentiment']]
dr.plot()
plt.title('Sentiment');

# %%
dr = btc_df[['num_tweets']]
dr.plot()
plt.title('Number of Tweets');

# %%
pd.plotting.scatter_matrix(btc_df[['Open','tb_polarity','tb_subjectivity','hf_sentiment','fl_sentiment']], alpha=0.2, diagonal='kde',figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f13207b5d10>,
# ...
#       dtype=object)
